# %% [markdown]
# # Getting Financial Data - Google Finance

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import pandas_datareader as web
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %%
start = datetime.date(2015 , 1 , 1)
end = datetime.date.today()

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
stonks = ['AAPL' , 'TSLA', 'TWTR' , 'IBM' , 'LNKD']

# %% [markdown]
# ### Step 4. Read the data from google, assign to df and print it

# %%
#Aqui não entendi porque deu erro na leitura do Linkedin
df = web.DataReader(stonks, 'yahoo', start=start, end=end)
# Out:
# /home/larissa/miniconda3/envs/treinamento-octos/lib/python3.8/site-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'LNKD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)

# %%
df
# Out:
# Attributes   Adj Close                                                Close  \
# Symbols           AAPL         TSLA       TWTR         IBM LNKD        AAPL
# Date
# 2015-01-02   99.766006   219.309998  36.560001  125.882919  NaN  109.330002
# 2015-01-05   96.955429   210.089996  36.380001  123.902168  NaN  106.250000
# 2015-01-06   96.964584   211.279999  38.759998  121.230103  NaN  106.260002
# 2015-01-07   98.324242   210.949997  37.279999  120.437820  NaN  107.750000
# 2015-01-08  102.102089   210.619995  39.090000  123.055511  NaN  111.889999
# ...                ...          ...        ...         ...  ...         ...
# 2020-08-03  434.965759  1485.000000  36.389999  122.703392  NaN  435.750000
# 2020-08-04  437.870514  1487.000000  36.349998  124.213615  NaN  438.660004
# 2020-08-05  439.457642  1485.020020  36.790001  123.828659  NaN  440.250000
# 2020-08-06  454.790009  1489.579956  37.689999  124.490005  NaN  455.609985
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
df.dtypes
# Out:
# Attributes  Symbols
# Adj Close   AAPL       float64
#             TSLA       float64
#             TWTR       float64
#             IBM        float64
#             LNKD       float64
# Close       AAPL       float64
#             TSLA       float64
#             TWTR       float64
#             IBM        float64
#             LNKD       float64
# High        AAPL       float64
#             TSLA       float64
#             TWTR       float64
#             IBM        float64
#             LNKD       float64
# Low         AAPL       float64
#             TSLA       float64
#             TWTR       float64
#             IBM        float64
#             LNKD       float64
# Open        AAPL       float64
#             TSLA       float64
#             TWTR       float64
#             IBM        float64
#             LNKD       float64
# Volume      AAPL       float64
#             TSLA       float64
#             TWTR       float64
#             IBM        float64
# ...

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Panel structure go to [documentation](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#panel)

# %%
df.items
# Out:
# <bound method DataFrame.items of Attributes   Adj Close                                                Close  \
# Symbols           AAPL         TSLA       TWTR         IBM LNKD        AAPL
# Date
# 2015-01-02   99.766006   219.309998  36.560001  125.882919  NaN  109.330002
# 2015-01-05   96.955429   210.089996  36.380001  123.902168  NaN  106.250000
# 2015-01-06   96.964584   211.279999  38.759998  121.230103  NaN  106.260002
# 2015-01-07   98.324242   210.949997  37.279999  120.437820  NaN  107.750000
# 2015-01-08  102.102089   210.619995  39.090000  123.055511  NaN  111.889999
# ...                ...          ...        ...         ...  ...         ...
# 2020-08-03  434.965759  1485.000000  36.389999  122.703392  NaN  435.750000
# 2020-08-04  437.870514  1487.000000  36.349998  124.213615  NaN  438.660004
# 2020-08-05  439.457642  1485.020020  36.790001  123.828659  NaN  440.250000
# 2020-08-06  454.790009  1489.579956  37.689999  124.490005  NaN  455.609985
# ...

# %% [markdown]
# ### Step 7. Good, now we know  the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
vol = df['Volume']
vol
# Out:
# Symbols           AAPL       TSLA        TWTR        IBM  LNKD
# Date
# 2015-01-02  53204600.0  4764400.0  12062500.0  5525500.0   NaN
# 2015-01-05  64285500.0  5368500.0  15062700.0  4880400.0   NaN
# 2015-01-06  65797100.0  6261900.0  33050800.0  6146700.0   NaN
# 2015-01-07  40105900.0  2968400.0  22675700.0  4701800.0   NaN
# 2015-01-08  59364500.0  3442500.0  19190400.0  4236800.0   NaN
# ...                ...        ...         ...        ...   ...
# 2020-08-03  77037800.0  8809300.0  15488000.0  3526100.0   NaN
# 2020-08-04  43267900.0  8415000.0  10596700.0  3466100.0   NaN
# 2020-08-05  30498000.0  4978000.0  10052100.0  3675400.0   NaN
# 2020-08-06  50607200.0  5992300.0  10478900.0  3417100.0   NaN
# 2020-08-07  49453300.0  8883500.0  11335100.0  3651000.0   NaN
#
# [1410 rows x 5 columns]

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %% [markdown]
# Aqui vou precisar de uma ajuda. Eu entendi que deveríamos separar o df em Semanas e seria a semana de cada ano. Exemplo: Semana 1 de 2015, semana 1 de 2016 ... Tentei de algumas formas mas nenhuma deu certo.

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
df['Volume'].resample('Y').sum().head(1)
# Out:
# Symbols             AAPL          TSLA          TWTR           IBM  LNKD
# Date
# 2015-12-31  1.306605e+10  1.088218e+09  5.361489e+09  1.105583e+09   0.0

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# O gráfico abaixo mostra a variação da média dos volumes em cada ano

# %%
x = df['Volume'].resample('Y').mean()
x
# Out:
# Symbols             AAPL          TSLA          TWTR           IBM  LNKD
# Date
# 2015-12-31  5.184940e+07  4.318325e+06  2.127575e+07  4.387233e+06   NaN
# 2016-12-31  3.842253e+07  4.612546e+06  2.571148e+07  4.042086e+06   NaN
# 2017-12-31  2.713457e+07  6.334786e+06  1.757268e+07  4.267596e+06   NaN
# 2018-12-31  3.402006e+07  8.612107e+06  2.850942e+07  5.452433e+06   NaN
# 2019-12-31  2.803096e+07  9.159040e+06  1.539983e+07  3.756727e+06   NaN
# 2020-12-31  4.205700e+07  1.728216e+07  2.192548e+07  5.907619e+06   NaN

# %%
sns.relplot(data = x , kind="line")
plt.ylabel('Volume')
plt.show()
