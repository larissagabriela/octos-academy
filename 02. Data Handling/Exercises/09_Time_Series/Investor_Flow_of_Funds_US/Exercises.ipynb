# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %%
url = 'https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv'
pd.read_csv(url)
# Out:
#           Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0   2012-12-05         -7426            -6060         -1367     -74
# 1   2012-12-12         -8783            -7520         -1263     123
# 2   2012-12-19         -5496            -5470           -26     -73
# 3   2012-12-26         -4451            -4076          -375     550
# 4   2013-01-02        -11156            -9622         -1533    -158
# 5   2013-01-09         14817             7995          6821    2888
# 6   2014-04-02          3155              938          2217     265
# 7   2014-04-09          5761             2080          3681    1482
# 8   2014-04-16          2286              634          1652    1186
# 9   2014-04-23          3530             1392          2138    1239
# 10  2014-04-30         -3890            -3996           106     759
# 11  2014-05-07           632            -2006          2639    -340
# 12  2014-05-14         -1079            -2321          1242    1188
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
x = pd.read_csv(url)

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %% [markdown]
# Aqui nesse Step eu acabei respondendo outras perguntas. Primeiro defini a coluna Date como índice e converti para o tipo Datetime e com isso quando coloco x.index e aparece a freq. De primeirs, olhando o dataset imaginei que a frequência seria semanal.

# %%
x = x.set_index('Date')

# %%
x.index = pd.to_datetime(x.index)

# %%
x.index
# Out:
# DatetimeIndex(['2012-12-05', '2012-12-12', '2012-12-19', '2012-12-26',
#                '2013-01-02', '2013-01-09', '2014-04-02', '2014-04-09',
#                '2014-04-16', '2014-04-23', '2014-04-30', '2014-05-07',
#                '2014-05-14', '2014-05-21', '2014-05-28', '2014-06-04',
#                '2014-06-11', '2014-06-18', '2014-06-25', '2014-07-02',
#                '2014-07-09', '2014-07-30', '2014-08-06', '2014-08-13',
#                '2014-08-20', '2014-08-27', '2014-09-03', '2014-09-10',
#                '2014-11-05', '2014-11-12', '2014-11-19', '2014-11-25',
#                '2015-01-07', '2015-01-14', '2015-01-21', '2015-01-28',
#                '2015-02-04', '2015-02-11', '2015-03-04', '2015-03-11',
#                '2015-03-18', '2015-03-25', '2015-04-01', '2015-04-08'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
#Feito no Step 4

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
#Antes de converter para DateTime era um object

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
#Feito no Step 4

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
monthly = x.groupby(x.index.to_period('M')).sum()

# %%
monthly
# Out:
#          Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12        -26156           -23126         -3031     526        9848
# 2013-01          3661            -1627          5288    2730       12149
# 2014-04         10842             1048          9794    4931        8493
# 2014-05         -2203            -8720          6518    3172       13767
# 2014-06          2319            -6546          8865    4588        9715
# 2014-07         -7051           -11128          4078    2666        7506
# 2014-08          1943            -5508          7452    1885        1897
# 2014-09         -2767            -6596          3829    1599        3984
# 2014-11         -2753            -7239          4485     729       14528
# 2015-01          3471            -1164          4635    1729        7368
# 2015-02          5508             3509          1999    1752        9099
# 2015-03          5691            -8176         13867    2829        9138
# ...

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
#Fazendo acima nao vi NaN, mas usaria o .dropna()
monthly = monthly.dropna()

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
year = x.groupby(x.index.to_period('A')).sum()
year
# Out:
#       Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012        -26156           -23126         -3031     526        9848
# 2013          3661            -1627          5288    2730       12149
# 2014           330           -44689         45021   19570       59890
# 2015         15049           -10459         25508    7280       26028
#
#       Taxable Bond  Municipal Bond  Total
# Date
# 2012         12613           -2765 -15782
# 2013          9414            2735  18540
# 2014         44994           14896  79787
# 2015         17986            8041  48357

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# Aqui fiz 3 gráficos que mostram a variação da coluna 'Total Equity' e da coluna 'Total' considerando 3 intervalos diferentes. Observando a relação entre eles.

# %%
x[['Total' , 'Total Equity']].plot()

# %%
monthly[['Total' , 'Total Equity']].plot()

# %%
year[['Total' , 'Total Equity']].plot()
